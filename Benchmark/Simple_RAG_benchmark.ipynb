# %% [markdown]
# # Simple RAG Benchmark
# ### Benchmark Evaluation for Illinois Statutes RAG System
#
# To evaluate our **Illinois Statutes RAG system**, we created custom benchmark questions due to the absence of pre-existing, Illinois-specific questions. The questions primarily focus on the following areas:
#
# - **Education**
# - **Health**
# - **Regulation**
#
# These areas address policies, public safety, and compliance rules.
#
# ## Question Design
#
# ### Total Questions: 45
#
# #### 1. **True/False Statements** (15 Questions)
# - Assess whether a given statement aligns with the statutes.
# - **Example Question**: Can a licensed currency exchange operate at multiple locations under the same license?
#   **Example Answer**: No.
#
# #### 2. **Short-Answer Questions** (30 Questions)
# - Fact-based questions requiring specific answers about acts or provisions.
# - **Example Question**: What is required for a 16-year-old to donate blood?
#   **Example Answer**: Written permission or authorization from their parent or guardian.

# %%
# Importing necessary libraries and modules
import json
import vertexai
from vertexai.preview.generative_models import GenerativeModel
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.chains import ConversationalRetrievalChain
from langchain_google_vertexai import VertexAIEmbeddings
from langchain_google_community import BigQueryVectorStore
from langchain_google_vertexai import VertexAI
from langchain.chains import RetrievalQA
from langchain.memory import ConversationBufferMemory

# %%
# Initialize Vertex AI
PROJECT_ID = "mlds-cap-2024-lexlead-advisor"  
REGION = "us-central1"         
vertexai.init(project=PROJECT_ID, location=REGION)

# Load the Gemini 1.5 Pro model (for text-based legal question-answering)
generative_model_gemini_15_pro = GenerativeModel("gemini-1.5-pro-002")
generative_model_gemini_15_non_pro = GenerativeModel("gemini-1.5-flash-002")

models = [
    ("Gemini 1.5 Pro", generative_model_gemini_15_pro), 
    ("Gemini 1.5 Flash", generative_model_gemini_15_non_pro)
]

# %%
# Initialize the VertexAI Embedding model
embedding_model = VertexAIEmbeddings(
    model_name="textembedding-gecko@latest", 
    project=PROJECT_ID
)

# Initialize the BigQuery Vector Store
bq_store = BigQueryVectorStore(
    project_id=PROJECT_ID,
    dataset_name="test_IL",
    table_name="statues",
    location=REGION,
    embedding=embedding_model
)
# Out:
# BigQuery table mlds-cap-2024-lexlead-advisor.test_IL.statues initialized/validated as persistent storage. Access via BigQuery console:
#  https://console.cloud.google.com/bigquery?project=mlds-cap-2024-lexlead-advisor&ws=!1m5!1m4!4m3!1smlds-cap-2024-lexlead-advisor!2stest_IL!3sstatues

# %% [markdown]
# ### Example Implementation

# %%
# Initialize the Language Model (LLM) using Vertex AI
llm = VertexAI(model_name="gemini-1.5-pro-002")

# Set up the retriever with a BigQuery vector store
retriever = bq_store.as_retriever(search_kwargs={"k": 200})

# Create a memory buffer for conversational context
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

# Build a Conversational Retrieval Chain
conversational_retrieval = ConversationalRetrievalChain.from_llm(
    llm=llm, retriever=retriever, memory=memory
)
# Define the search query for the conversational retrieval system
search_query = "Does the definition of tattooing include procedures like permanent makeup for lip coloring or eyeliner? (Yes or No)"

# Execute the query and retrieve the answer
conversational_retrieval.invoke(search_query)["answer"]
# Out:
# 'Yes\n'

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### TRUE/FALSE Statement Question Overview

# %%
file_path =  "binary_benchmark_question.json"

# Read the JSON file
with open(file_path, "r") as file:
    data = json.load(file)

# Access questions and answers
questions = data.get("questions", [])
answers = data.get("answers", [])

# Print all questions and answers
for i, (question, answer) in enumerate(zip(questions, answers), start=1):
    print(f"Question {i}: {question}")
    print(f"Answer {i}: {answer}\n")
# Out:
# Question 1: Are licenses required to operate community or ambulatory currency exchanges? (yes or no)
# Answer 1: Yes.
#
# Question 2: Can a licensed currency exchange operate at multiple locations under the same license? (yes or no)
# Answer 2: No.
#
# Question 3: Is it mandatory for a single female borrower to have a cosigner if a single male borrower under similar conditions does not require one? (yes or no)
# Answer 3: No.
#
# Question 4: Can campground licenses be transferred to another operator? (yes or no)
# Answer 4: No.
#
# Question 5: Are campus media produced by students at state-sponsored higher education institutions considered public forums for student expression? (yes or no)
# Answer 5: Yes
#
# Question 6: Are Illinois residents obligated to submit ACT or SAT scores when applying to public universities in the state?(yes or no)
# Answer 6: No.
#
# Question 7: Are institutions allowed to implement a more lenient transcript policy than the minimum requirements?(yes or no)
# Answer 7: Yes.
#
# Question 8: Does campus media expression made by students represent official campus policy or speech attributable to the institution?(yes or no)
# Answer 8: No.
#
# Question 9: Are state-sponsored institutions immune from lawsuits arising from expressions made in campus media, except for their own expression?(yes or no)
# Answer 9: Yes.
#
# Question 10: Can a member of the community mental health board be removed for absenteeism or misconduct?(yes or no)
# Answer 10: Yes.
#
# Question 11: Does the definition of tattooing include procedures like permanent makeup for lip coloring or eyeliner? (Yes or No)
# Answer 11: Yes
#
# Question 12: Is the use of latex gloves by employees in food service establishments prohibited as of January 1, 2023?(Yes or No)
# Answer 12: Yes
#
# Question 13: Are properties constructed after 1978 the primary focus of the CLEAR-WIN Program for addressing lead hazards?(Yes or No)
# Answer 13: No
#
# Question 14: Are windows considered a lower risk for lead exposure compared to other housing components, according to the findings of the Illinois General Assembly?(Yes or No)
# Answer 14: No.
#
# Question 15: Are properties built before 1950 statistically more likely to contain lead-based paint hazards compared to newer buildings?
# Answer 15: Yes.

# %% [markdown]
# ### Benchmark Analysis On True/False Question

# %%
import time
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type, RetryError
from google.api_core.exceptions import ResourceExhausted

# Initialize the RAG system
retriever = bq_store.as_retriever(search_kwargs={"k": 250})
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
conversational_retrieval = ConversationalRetrievalChain.from_llm(
    llm=VertexAI(model_name="gemini-1.5-pro-002"), retriever=retriever, memory=memory
)# Combine LLM, retriever, and memory for RAG-based interactions

# Custom exception for empty or filtered responses
class EmptyResponseError(Exception):
    pass

# Define a function to generate responses with retry logic
@retry(
    stop=stop_after_attempt(2),
    wait=wait_exponential(multiplier=1, min=5, max=120),
    retry=retry_if_exception_type((ResourceExhausted, EmptyResponseError))
)
def generate_with_retry_rag(prompt):
    """
    Generate a response using the RAG system with retry logic.
    
    Args:
        prompt (str): Input prompt to the RAG system.
    
    Returns:
        str: Normalized response from the RAG system.
    """
    try:
        response = conversational_retrieval.invoke(prompt)["answer"]

        # Check if the response is not empty
        if not response or not response.strip():
            raise EmptyResponseError("RAG response is empty or blocked.")
        
      # Normalize and check for "I don't know" or similar insufficient responses
        normalized_response = response.strip().lower()
        if is_response_insufficient(normalized_response):
            raise EmptyResponseError("RAG response indicates insufficient information.")
        
        return normalized_response  # Return the valid response'''

    except Exception as e:
        print(f"Error encountered while generating RAG response: {e}")
        raise EmptyResponseError("RAG content is blocked or empty.") from e
@retry(
    stop=stop_after_attempt(2),  # Retry up to 7 times
    wait=wait_exponential(multiplier=1, min=5, max=120),  # Exponential backoff with 5s min and 120s max
    retry=retry_if_exception_type((ResourceExhausted, EmptyResponseError))
)

def is_response_insufficient(response):
    """
    Determines if the response is insufficient based on predefined criteria.
    
    Args:
        response (str): The normalized response text.
    
    Returns:
        bool: True if the response is insufficient, False otherwise.
    """
    insufficient_phrases = [
        "i don't know",
        "unable to find",
        "not sure",
        "cannot determine",
        "no information available",
        "please provide more context",
        "i cannot answer",
        "cannot be answered"
    ]
    # Check if response contains any insufficient phrases
    return any(phrase in response for phrase in insufficient_phrases)

               
def validate_with_gemini(question, generated_answer, ground_truth):
    """
    Validate the generated answer using Gemini 1.5 Pro with retry logic.
    """
    gemini_model = generative_model_gemini_15_pro

    prompt = f"""
    Question: {question}

    Generated Answer: {generated_answer}

    Ground Truth Answer: {ground_truth}

    Evaluate the generated answer. Determine if it is correct or incorrect based on the ground truth. It is normal for the generated answer to provide more information than the ground truth. If the generated answer conveys the same meaning as the ground truth or provides additional relevant details without contradicting the ground truth, consider it correct. Minor differences in wording or phrasing should not be penalized. Provide reasoning for your evaluation and then output one of the following:
    - "Correct" if the generated answer is consistent with the ground truth in meaning, even if phrasing differ or the answer is providing more additional details and information.
    - "Incorrect" if the generated answer is inconsistent with the ground truth or introduces contradictions.

    """
    response = gemini_model.generate_content([prompt])

    # Ensure the response contains text
    if not response or not hasattr(response, 'text') or not response.text.strip():
        raise EmptyResponseError("Validation response is empty or blocked.")

    return response.text.strip() # Return the validation result


# Main evaluation loop
model_results = {} # Store results for different models
num_to_print = 20 # Number of questions to print details for

# Start RAG benchmarking
print("Evaluating RAG system\n")
total = len(questions)  # Total number of questions
correct_count = 0  # Reset correct count for RAG
question_times = []  # Track time taken for each question

evaluation_start_time = time.time()# Start timing for the entire evaluation

for i in range(total):
    print(f"Processing question {i + 1} out of {total}")  # Track which question is being processed
    question_start_time = time.time()  # Start timing for the current question

    question = questions[i]
    ground_truth = answers[i]

    prompt = f"""
    You are an expert in Illinois Education Law who are answering client legal question professionally. Answer the following question by reasoning step-by-step. 
    For questions labeled (yes or no) answer yes or no before reasoning. If the text does not provide sufficient information to provide a clear answer, just answer "i don't know" before providing more information.

    Question: {question}
    """

    try:
        # Generate and validate the response
        model_response = generate_with_retry_rag(prompt)
        validation_result = validate_with_gemini(question, model_response, ground_truth)
        validation_result = validation_result.split("\n")[0].strip().lower()  # Parse the first line for "correct" or "incorrect"

        if "incorrect" not in validation_result:  # Count correct answers
            correct_count += 1

        # Record time taken for the question
        question_end_time = time.time()
        question_time = question_end_time - question_start_time
        question_times.append(question_time)

        # Print question details if within the specified range
        if i < num_to_print:
            print(f"Question {i + 1}: {question}")
            print(f"Ground Truth: {ground_truth}")
            print(f"RAG Response: {model_response}")
            print(f"Validation Result: {validation_result}")
            print(f"Time Taken: {question_time:.2f} seconds\n")
            print("-" * 80)

    except RetryError as e:
        # Handle retries being exhausted
        print(f"Failed to get a response for question {i + 1} after 2 retries.")
        last_exception = e.last_attempt.exception()
        print(f"Last exception: {last_exception}")
        #print("Waiting 5 minutes before continuing to prevent further quota issues.")
       #time.sleep(300)
        continue  # Skip to the next question if retries are exhausted

# End timing for the entire evaluation
evaluation_end_time = time.time()
total_evaluation_time = evaluation_end_time - evaluation_start_time

# Calculate accuracy
accuracy = (correct_count / total) * 100  # Calculate as a percentage
model_results["RAG"] = {
    "Total Questions Evaluated": total,
    "Correctly Matched Answers": correct_count,
    "Accuracy": accuracy,  # Store accuracy as a percentage
    "Total Time (seconds)": total_evaluation_time,
    "Average Time per Question (seconds)": sum(question_times) / len(question_times) if question_times else 0,
}

# Print results
print("\nFinal Results for RAG System:")
for model_name, results in model_results.items():
    print(f"Model: {model_name}")
    print(f"Total Questions Evaluated: {results['Total Questions Evaluated']}")
    print(f"Correctly Matched Answers: {results['Correctly Matched Answers']}")
    print(f"Accuracy: {results['Accuracy']:.2f}%")
    print(f"Total Time: {results['Total Time (seconds)']:.2f} seconds")
    print(f"Average Time per Question: {results['Average Time per Question (seconds)']:.2f} seconds")
    print("=" * 100)
# Out:
# Evaluating RAG system
#
# Processing question 1 out of 15
# Question 1: Are licenses required to operate community or ambulatory currency exchanges? (yes or no)
# Ground Truth: Yes.
# RAG Response: yes.
#
# the provided text explicitly states in sec. 2. license required; violation; injunction of the currency exchange act (205 ilcs 405/2) that:
#
# "no person, firm, association, partnership, limited liability company, or corporation shall engage in the business of a community currency exchange or in the business of an ambulatory currency exchange without first securing a license to do so from the secretary."
# Validation Result: correct. the generated answer correctly identifies that a license *is* required to operate community or ambulatory currency exchanges.  the provided text excerpt from the illinois currency exchange act explicitly confirms this.  the additional context from the legal statute strengthens the answer.
# Time Taken: 40.36 seconds
#
# --------------------------------------------------------------------------------
# Processing question 2 out of 15
# Question 2: Can a licensed currency exchange operate at multiple locations under the same license? (yes or no)
# Ground Truth: No.
# RAG Response: no
# Validation Result: correct
# Time Taken: 16.90 seconds
#
# --------------------------------------------------------------------------------
# Processing question 3 out of 15
# Question 3: Is it mandatory for a single female borrower to have a cosigner if a single male borrower under similar conditions does not require one? (yes or no)
# Ground Truth: No.
# RAG Response: no.
# Validation Result: correct
# Time Taken: 63.99 seconds
#
# --------------------------------------------------------------------------------
# Processing question 4 out of 15
# Question 4: Can campground licenses be transferred to another operator? (yes or no)
# Ground Truth: No.
# RAG Response: yes
# Validation Result: incorrect.
# Time Taken: 12.18 seconds
#
# --------------------------------------------------------------------------------
# Processing question 5 out of 15
# Question 5: Are campus media produced by students at state-sponsored higher education institutions considered public forums for student expression? (yes or no)
# Ground Truth: Yes
# RAG Response: yes, according to the provided text, (110 ilcs 13/10) sec. 10 of the college campus press act states: "all campus media produced primarily by students at a state-sponsored institution of higher learning is a public forum for expression by the student journalists and editors at the particular institution."
# Validation Result: correct
# Time Taken: 41.30 seconds
#
# --------------------------------------------------------------------------------
# Processing question 6 out of 15
# Question 6: Are Illinois residents obligated to submit ACT or SAT scores when applying to public universities in the state?(yes or no)
# Ground Truth: No.
# RAG Response: no. illinois residents are not required to submit standardized test scores, such as act or sat, when applying to public universities in the state.  this is due to the higher education fair admissions act (110 ilcs 29/10), which mandates a test-optional policy for all illinois public institutions of higher education.  while institutions can still *accept* these scores, they cannot *require* them from illinois residents as part of the admissions process.
# Validation Result: correct. the generated answer accurately reflects the information in the ground truth.  it correctly states that illinois residents are not *required* to submit act or sat scores for admission to public universities.  the additional information about the higher education fair admissions act and the distinction between accepting and requiring scores further supports the answer and provides helpful context.
# Time Taken: 28.71 seconds
#
# --------------------------------------------------------------------------------
# Processing question 7 out of 15
# Question 7: Are institutions allowed to implement a more lenient transcript policy than the minimum requirements?(yes or no)
# Ground Truth: Yes.
# RAG Response: yes
# Validation Result: correct
# Time Taken: 19.63 seconds
#
# --------------------------------------------------------------------------------
# Processing question 8 out of 15
# Question 8: Does campus media expression made by students represent official campus policy or speech attributable to the institution?(yes or no)
# Ground Truth: No.
# RAG Response: no. section 25 of the college campus press act (110 ilcs 13/25) explicitly states that expression made by a collegiate student journalist, editor, or other contributor in campus media is neither an expression of campus policy nor speech attributable to a state-sponsored institution of higher learning.
# Validation Result: correct. the generated answer accurately reflects the ground truth that student media expression does not represent official campus policy or institutional speech.  it provides additional context by citing the relevant section of the college campus press act, which strengthens the answer without contradicting the core information.
# Time Taken: 34.01 seconds
#
# --------------------------------------------------------------------------------
# Processing question 9 out of 15
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 9 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 10 out of 15
# Question 10: Can a member of the community mental health board be removed for absenteeism or misconduct?(yes or no)
# Ground Truth: Yes.
# RAG Response: yes.  a community mental health board member in illinois can be removed for misconduct or neglect of duty by the chairman or president of the county board, with the approval of the county board.  while the law does not explicitly mention "absenteeism", neglect of duty could encompass excessive absences from meetings.
# Validation Result: correct. the generated answer correctly states that a community mental health board member can be removed for misconduct or neglect of duty, and it accurately explains that neglect of duty could encompass excessive absenteeism.  the additional information about the process in illinois provides helpful context and doesn't contradict the core answer.
# Time Taken: 13.42 seconds
#
# --------------------------------------------------------------------------------
# Processing question 11 out of 15
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 11 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 12 out of 15
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 12 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 13 out of 15
# Question 13: Are properties constructed after 1978 the primary focus of the CLEAR-WIN Program for addressing lead hazards?(Yes or No)
# Ground Truth: No
# RAG Response: no. the clear-win program focuses on pre-1978 homes.  public act 95-492 established clear-win as a pilot program to reduce potential lead hazards by replacing windows in low-income, pre-1978 homes.
# Validation Result: correct
# Time Taken: 36.93 seconds
#
# --------------------------------------------------------------------------------
# Processing question 14 out of 15
# Question 14: Are windows considered a lower risk for lead exposure compared to other housing components, according to the findings of the Illinois General Assembly?(Yes or No)
# Ground Truth: No.
# RAG Response: no. windows are considered a *higher* risk for lead exposure than other components of a housing unit.  several sections of text provided reference this.
# Validation Result: incorrect. the generated answer states windows are a *higher* risk, which contradicts the ground truth "no", implying they are *not* a lower risk, but rather an equal or higher risk.  the question asks if they are *lower* risk.  the generated answer says the opposite.
# Time Taken: 17.45 seconds
#
# --------------------------------------------------------------------------------
# Processing question 15 out of 15
# Question 15: Are properties built before 1950 statistically more likely to contain lead-based paint hazards compared to newer buildings?
# Ground Truth: Yes.
# RAG Response: yes.
# Validation Result: correct.
# Time Taken: 11.06 seconds
#
# --------------------------------------------------------------------------------
#
# Final Results for RAG System:
# Model: RAG
# Total Questions Evaluated: 15
# Correctly Matched Answers: 10
# Accuracy: 66.67%
# Total Time: 502.51 seconds
# Average Time per Question: 27.99 seconds
# ====================================================================================================

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Short-Answer Questions Overview

# %%
file_path =  "shortanswer_benchmark_question.json"

# Read the JSON file
with open(file_path, "r") as file:
    data = json.load(file)

# Access questions and answers
questions = data.get("questions", [])
answers = data.get("answers", [])

# Example: Print all questions and answers
for i, (question, answer) in enumerate(zip(questions, answers), start=1):
    print(f"Question {i}: {question}")
    print(f"Answer {i}: {answer}\n")
# Out:
# Question 1: What is required for a 16-year-old to donate blood?
# Answer 1: Written permission or authorization from their parent or guardian.
#
# Question 2: What change in blood donation rules takes effect on January 1, 2025?
# Answer 2: 17-year-olds can also have their blood typed.
#
# Question 3: What is the minimum distance from entrances, exits, windows, and ventilation intakes where smoking is prohibited under the Smoke-Free Illinois Act?
# Answer 3: 15 feet
#
# Question 4: What penalties are imposed on individuals who smoke in prohibited areas under the Smoke-Free Illinois Act?
# Answer 4: Under the Smoke Free Illinois Act, a person who smokes in a prohibited area is liable for a civil penalty of $100 for the first offense and $250 for each subsequent offense.
#
# Question 5: Which department is responsible for administering the Safe Bottled Water Act?
# Answer 5: The Department of Public Health.
#
# Question 6: How frequently must the Department of Public Health inspect water-bottling plants and private water sources?
# Answer 6: The Department of Public Health must inspect water-bottling plants and private water sources at least once a year.
#
# Question 7: Under what conditions can a person package water for public emergencies without obtaining a water bottling license?
# Answer 7: A person can package water for public emergencies with written permission from the Department if the public drinking water supply is interrupted or compromised.
#
# Question 8: What is the purpose of the Children's Mental Health Partnership?
# Answer 8: The Partnership advises state agencies on strategies to provide comprehensive and coordinated mental health services for children from birth to age 25 and their families.
#
# Question 9: By when must the Children's Mental Health Partnership submit recommendations for updates to the Act?
# Answer 9: Recommendations must be submitted by January 1, 2027.
#
# Question 10: What is the maximum number of individuals that can be served in a single Project HELP home, and under what circumstances can this limit be exceeded?
# Answer 10: Each Project HELP home typically serves one individual. This limit may be waived in exceptional circumstances, but no more than two individuals may be served in the same home.
#
# Question 11: Under the Community Support Systems Act, what is the primary target population for the developed systems?
# Answer 11: The primary target population includes individuals with chronic mental illnesses who are extended or repeated users of intensive mental health services.
#
# Question 12: What is the public policy of Illinois regarding plagiarism in institutions of higher education?
# Answer 12: Assisting or promoting plagiarism in higher education institutions is against the public policy of Illinois.
#
# Question 13: Who can initiate civil proceedings under the Academic Plagiarism Act to address plagiarism-related activities?
# Answer 13: The Attorney General or the State's Attorney of the county where the accredited institution of higher education is located can initiate civil proceedings.  This is done upon written petition by the chief executive officer of the campus.
#
# Question 14: Under what conditions can the court issue an injunction for academic paper-related activities under the Academic Plagiarism Act?
# Answer 14: The court may issue an injunction if:The preparer, advertiser, or seller has knowingly engaged in conduct leading to the submission of academic papers, substantially unchanged, as original work by another person for academic credit.The public interest requires the injunction to prevent future occurrences.
#
# Question 15: When did the test-optional admissions policy become mandatory for Illinois colleges
# Answer 15: The policy came into effect on January 1, 2022.
#
# Question 16: What is the main goal of the statewide teacher preparation initiative targeting hard-to-staff schools in Illinois?
# Answer 16: To prepare skilled teachers who will remain in hard-to-staff schools or teaching positions and increase diversity in the teaching workforce.
#
# Question 17: What types of schools are defined as hard-to-staff within the context of this teacher initiative?
# Answer 17: Schools serving a high percentage of low-income students or programs like Head Start where over 40% of children receive subsidized care.
#
# Question 18: What financial information must Illinois public universities provide on an undergraduate tuition bill?
# Answer 18: Illinois public universities must provide a statement on or with the tuition bill that details: 1. The total amount of financial support the university received from the General Assembly and the Governor, including amounts from the General Revenue Fund and the Education Assistance Fund.2. The average tuition subsidy received by resident undergraduate full-time students.
#
# Question 19: Who is responsible for calculating the average tuition subsidy provided to students in Illinois public universities, and when is this information shared?
# Answer 19: The Illinois Board of Higher Education is responsible and must provide the calculation to universities by March 1 of each year.
#
# Question 20: By what date must institutions report their financial-based transcript hold policies and statistics?
# Answer 20: Institutions of higher education in Illinois must report this information on or before July 1, 2024, and on or before each July 1 thereafter.
#
# Question 21: What expenses are reimbursed for members of the State Banking Board of Illinois?
# Answer 21: Members are reimbursed for ordinary and necessary expenses incurred in attending board meetings.
#
# Question 22: What is required to operate a community currency exchange?
# Answer 22: A separate, non-transferable license for each location is required to operate a community currency exchange.  The license is obtained from the Secretary of Financial and Professional Regulation after a thorough application and investigation process.
#
# Question 23: How is the annual license fee for a community currency exchange determined?
# Answer 23: The annual license fee for a community currency exchange is $400 per location and an additional $400 for each additional licensed location.
#
# Question 24: What are the filing obligations for a foreign banking corporation that amends its articles of incorporation?
# Answer 24: A foreign banking corporation holding a certificate of authority must file a copy of any amendment to its articles of incorporation with the Commissioner.
#
# Question 25: What responsibilities does a foreign banking corporation have regarding a registered agent and office in Illinois?
# Answer 25: The corporation must maintain a registered office and a registered agent in Illinois, with provisions to change or update this information as needed.
#
# Question 26: How is legal process served to a foreign banking corporation if it fails to maintain a registered agent?
# Answer 26: If a foreign banking corporation fails to maintain a registered agent in Illinois, the Commissioner of Banks and Real Estate becomes its agent for service of process.  Service is made by delivering duplicate copies of the process, notice, or demand to the Commissioner or an official in the banking department. The Commissioner then forwards a copy to the foreign banking corporation at its principal office.
#
# Question 27: What is the definition of blockchain in the context of decentralized records?
# Answer 27: an electronic record created by the use of a decentralized method by multiple parties to verify and store a digital record of transactions which is secured by the use of a cryptographic hash of previous transaction information.
#
# Question 28: What legal and regulatory mechanisms are supported for blockchain and financial technology adoption?
# Answer 28: Mechanisms that enable and promote the adoption of blockchain and financial technology in the state are included in promotional efforts.
#
# Question 29: What industries are targeted for economic development using blockchain and financial technology?
# Answer 29: Banking, insurance, retail and service businesses, and cryptocurrency for blockchain technology and financial technology-related economic development.
#
# Question 30: What is the purpose of licensing campgrounds and recreational areas?
# Answer 30: To ensure safety, cleanliness, and general sanitation, thereby protecting public health, safety, and welfare.

# %% [markdown]
# ### Benchmark Analysis on Short-Answer Questions

# %%
import time
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type, RetryError
from google.api_core.exceptions import ResourceExhausted
# Initialize the RAG system
retriever = bq_store.as_retriever(search_kwargs={"k": 250})
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
conversational_retrieval = ConversationalRetrievalChain.from_llm(
    llm=VertexAI(model_name="gemini-1.5-pro-002"), retriever=retriever, memory=memory
)

# Custom exception for empty or filtered responses
class EmptyResponseError(Exception):
    pass

# Function to generate a response using the RAG system with retry logic
@retry(
    stop=stop_after_attempt(2),
    wait=wait_exponential(multiplier=1, min=5, max=120),
    retry=retry_if_exception_type((ResourceExhausted, EmptyResponseError))
)
def generate_with_retry_rag(prompt):
    """
    Generate a response using the RAG system, with retries for errors.
    
    Args:
        prompt (str): Input query for the RAG system.
    
    Returns:
        str: Normalized response from the RAG system.
    
    Raises:
        EmptyResponseError: If the response is empty, blocked, or insufficient.
    """
    try:
        # Invoke the RAG system to generate a response
        response = conversational_retrieval.invoke(prompt)["answer"]

        # Check if the response is not empty
        if not response or not response.strip():
            raise EmptyResponseError("RAG response is empty or blocked.")
        
        # Normalize and validate the response
        normalized_response = response.strip().lower()
        if is_response_insufficient(normalized_response):
            raise EmptyResponseError("RAG response indicates insufficient information.")
        
        return normalized_response  # Return the valid response

    except Exception as e:
         # Handle any exception by raising a custom EmptyResponseError
        print(f"Error encountered while generating RAG response: {e}")
        raise EmptyResponseError("RAG content is blocked or empty.") from e
@retry(
    stop=stop_after_attempt(2),  # Retry up to 7 times
    wait=wait_exponential(multiplier=1, min=5, max=120),  # Exponential backoff with 5s min and 120s max
    retry=retry_if_exception_type((ResourceExhausted, EmptyResponseError))
)

# Function to check if a response is insufficient based on predefined criteria
def is_response_insufficient(response):
    """
    Determines if the response is insufficient based on predefined criteria.
    
    Args:
        response (str): The normalized response text.
    
    Returns:
        bool: True if the response is insufficient, False otherwise.
    """
    insufficient_phrases = [
        "i don't know",
        "unable to find",
        "not sure",
        "cannot determine",
        "no information available",
        "please provide more context",
        "i cannot answer",
        "cannot be answered"
    ]
    # Check if response contains any insufficient phrases
    return any(phrase in response for phrase in insufficient_phrases)

# Function to validate the RAG-generated answer using the Gemini model               
def validate_with_gemini(question, generated_answer, ground_truth):
    """
    Validate the generated answer using Gemini 1.5 Pro with retry logic.
    """
    gemini_model = generative_model_gemini_15_pro

    prompt = f"""
    Question: {question}

    Generated Answer: {generated_answer}

    Ground Truth Answer: {ground_truth}

    Evaluate the generated answer. Determine if it is correct or incorrect based on the ground truth. It is normal for the generated answer to provide more information than the ground truth. If the generated answer conveys the same meaning as the ground truth or provides additional relevant details without contradicting the ground truth, consider it correct. Minor differences in wording or phrasing should not be penalized. Provide reasoning for your evaluation and then output one of the following:
    - "Correct" if the generated answer is consistent with the ground truth in meaning, even if phrasing differ or the answer is providing more additional details and information.
    - "Incorrect" if the generated answer is inconsistent with the ground truth or introduces contradictions.
 Provide reasoning for your evaluation and then output one of the following:

    """
    response = gemini_model.generate_content([prompt])

    # Ensure the response contains text
    if not response or not hasattr(response, 'text') or not response.text.strip():
        raise EmptyResponseError("Validation response is empty or blocked.")

    return response.text.strip() # Return the validation result


# Main evaluation loop
model_results = {} # Dictionary to store evaluation results
num_to_print = 30 # Number of question details to print for inspection

# Start RAG benchmarking
print("Evaluating RAG system\n")
total = len(questions) # Total number of questions to evaluate
correct_count = 0  # Reset correct count for RAG
question_times = []  # Track time taken for each question

# Start timing for the entire evaluation
evaluation_start_time = time.time()

for i in range(total):
    print(f"Processing question {i + 1} out of {total}")  # Track which question is being processed
    question_start_time = time.time()  # Start timing for the current question

    question = questions[i]
    ground_truth = answers[i]
    # Generate a prompt for the RAG system
    prompt = f"""
    You are an expert in Illinois Education Law who are answering client legal question professionally. Answer the following question by reasoning step-by-step. 
    For questions labeled (yes or no) answer yes or no before reasoning. If the text does not provide sufficient information to provide a clear answer, just answer "i don't know" before providing more information.

    Question: {question}
    """

    try:
        # Generate a response and validate it
        model_response = generate_with_retry_rag(prompt)
        validation_result = validate_with_gemini(question, model_response, ground_truth)
        validation_result = validation_result.split("\n")[0].strip().lower()  # Parse the first line for "correct" or "incorrect"

        if "incorrect" not in validation_result:# Count correct responses
            correct_count += 1

        # Record time taken for the question
        question_end_time = time.time()
        question_time = question_end_time - question_start_time
        question_times.append(question_time)
        
        # Print details for the first `num_to_print` questions
        if i < num_to_print:
            print(f"Question {i + 1}: {question}")
            print(f"Ground Truth: {ground_truth}")
            print(f"RAG Response: {model_response}")
            print(f"Validation Result: {validation_result}")
            print(f"Time Taken: {question_time:.2f} seconds\n")
            print("-" * 80)

    except RetryError as e:
        # Handle retries being exhausted
        print(f"Failed to get a response for question {i + 1} after 2 retries.")
        last_exception = e.last_attempt.exception()
        print(f"Last exception: {last_exception}")
        #print("Waiting 5 minutes before continuing to prevent further quota issues.")
       #time.sleep(300)
        continue  # Skip to the next question if retries are exhausted

# End timing for the entire evaluation
evaluation_end_time = time.time()
total_evaluation_time = evaluation_end_time - evaluation_start_time

# Calculate accuracy
accuracy = (correct_count / total) * 100  # Calculate as a percentage
model_results["RAG"] = {
    "Total Questions Evaluated": total,
    "Correctly Matched Answers": correct_count,
    "Accuracy": accuracy,  # Store accuracy as a percentage
    "Total Time (seconds)": total_evaluation_time,
    "Average Time per Question (seconds)": sum(question_times) / len(question_times) if question_times else 0,
}

# Display the final evaluation results
print("\nFinal Results for RAG System:")
for model_name, results in model_results.items():
    print(f"Model: {model_name}")
    print(f"Total Questions Evaluated: {results['Total Questions Evaluated']}")
    print(f"Correctly Matched Answers: {results['Correctly Matched Answers']}")
    print(f"Accuracy: {results['Accuracy']:.2f}%")
    print(f"Total Time: {results['Total Time (seconds)']:.2f} seconds")
    print(f"Average Time per Question: {results['Average Time per Question (seconds)']:.2f} seconds")
    print("=" * 100)
# Out:
# Evaluating RAG system
#
# Processing question 1 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Question 1: What is required for a 16-year-old to donate blood?
# Ground Truth: Written permission or authorization from their parent or guardian.
# RAG Response: a 16-year-old may donate blood with written permission or authorization from their parent or guardian.
# Validation Result: correct
# Time Taken: 102.45 seconds
#
# --------------------------------------------------------------------------------
# Processing question 2 out of 30
# Question 2: What change in blood donation rules takes effect on January 1, 2025?
# Ground Truth: 17-year-olds can also have their blood typed.
# RAG Response: 16-year-olds will be able to donate blood with written parental/guardian permission.
# Validation Result: incorrect
# Time Taken: 71.31 seconds
#
# --------------------------------------------------------------------------------
# Processing question 3 out of 30
# Question 3: What is the minimum distance from entrances, exits, windows, and ventilation intakes where smoking is prohibited under the Smoke-Free Illinois Act?
# Ground Truth: 15 feet
# RAG Response: 15 feet
# Validation Result: correct
# Time Taken: 40.22 seconds
#
# --------------------------------------------------------------------------------
# Processing question 4 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 4 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 5 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 5 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 6 out of 30
# Question 6: How frequently must the Department of Public Health inspect water-bottling plants and private water sources?
# Ground Truth: The Department of Public Health must inspect water-bottling plants and private water sources at least once a year.
# RAG Response: the text states that water analyses must be conducted and reported annually, unless the department finds that reasonable action requires either more or less frequent analysis.  while this speaks to the frequency of water analysis, it doesn't specify the frequency of inspections of the facilities themselves. therefore, the provided text does not contain the answer.
# Validation Result: incorrect
# Time Taken: 49.84 seconds
#
# --------------------------------------------------------------------------------
# Processing question 7 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 7 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 8 out of 30
# Question 8: What is the purpose of the Children's Mental Health Partnership?
# Ground Truth: The Partnership advises state agencies on strategies to provide comprehensive and coordinated mental health services for children from birth to age 25 and their families.
# RAG Response: the children's mental health partnership advises state agencies on designing and implementing strategies to provide comprehensive and coordinated services for children from birth to age 25 and their families to address children's mental health needs across a full continuum of care, including social determinants of health, prevention, early identification, and treatment.
# Validation Result: correct
# Time Taken: 61.11 seconds
#
# --------------------------------------------------------------------------------
# Processing question 9 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 9 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 10 out of 30
# Question 10: What is the maximum number of individuals that can be served in a single Project HELP home, and under what circumstances can this limit be exceeded?
# Ground Truth: Each Project HELP home typically serves one individual. This limit may be waived in exceptional circumstances, but no more than two individuals may be served in the same home.
# RAG Response: the provided text mentions that qualified residences, which could include project help homes, can house a maximum of four unrelated individuals.  it also states that "time-limited exceptions to this definition may be developed" if there are not enough qualified residences to meet demand.  therefore, four is the maximum number of unrelated individuals allowed, but this limit may be exceeded under certain time-limited circumstances when demand exceeds the available housing.
# Validation Result: incorrect
# Time Taken: 100.71 seconds
#
# --------------------------------------------------------------------------------
# Processing question 11 out of 30
# Question 11: Under the Community Support Systems Act, what is the primary target population for the developed systems?
# Ground Truth: The primary target population includes individuals with chronic mental illnesses who are extended or repeated users of intensive mental health services.
# RAG Response: the provided text repeatedly refers to "persons with disabilities," including those with developmental disabilities, mental illness, physical disabilities, and autism.  therefore, individuals with disabilities are a primary target population.  the text also mentions services for the elderly.
# Validation Result: incorrect
# Time Taken: 24.03 seconds
#
# --------------------------------------------------------------------------------
# Processing question 12 out of 30
# Question 12: What is the public policy of Illinois regarding plagiarism in institutions of higher education?
# Ground Truth: Assisting or promoting plagiarism in higher education institutions is against the public policy of Illinois.
# RAG Response: the provided text states that the board of higher education may not approve any application for a certificate of approval that has been plagiarized, in part or in whole. (110 ilcs 1005/4)  this indicates a clear policy against plagiarism in the context of applications for certificates of approval for post-secondary educational institutions.  the text doesn't offer broader information regarding plagiarism in other higher education contexts such as student work.
# Validation Result: incorrect
# Time Taken: 16.39 seconds
#
# --------------------------------------------------------------------------------
# Processing question 13 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 13 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 14 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 14 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 15 out of 30
# Question 15: When did the test-optional admissions policy become mandatory for Illinois colleges
# Ground Truth: The policy came into effect on January 1, 2022.
# RAG Response: january 1, 2022
# Validation Result: correct
# Time Taken: 13.48 seconds
#
# --------------------------------------------------------------------------------
# Processing question 16 out of 30
# Question 16: What is the main goal of the statewide teacher preparation initiative targeting hard-to-staff schools in Illinois?
# Ground Truth: To prepare skilled teachers who will remain in hard-to-staff schools or teaching positions and increase diversity in the teaching workforce.
# RAG Response: the main goal of the grow your own teacher education initiative is to prepare highly skilled, committed teachers who will teach in hard-to-staff schools and hard-to-staff teaching positions (including within the department of juvenile justice school district) and who will remain in these schools for substantial periods of time.  a key focus is on placing teachers in hard-to-staff schools serving a substantial percentage of low-income students, and increasing teacher diversity based on race and ethnicity.
# Validation Result: correct
# Time Taken: 17.19 seconds
#
# --------------------------------------------------------------------------------
# Processing question 17 out of 30
# Question 17: What types of schools are defined as hard-to-staff within the context of this teacher initiative?
# Ground Truth: Schools serving a high percentage of low-income students or programs like Head Start where over 40% of children receive subsidized care.
# RAG Response: hard-to-staff schools under the grow your own teacher education initiative include those serving a substantial percentage of low-income students, schools with hard-to-staff teaching positions, and schools within the department of juvenile justice school district.  additionally, a "hard-to-staff school" is defined in another section of the illinois school code as a public school in which no less than 30% of the student enrollment is considered low-income.  another definition considers a "hard-to-staff school" as one that ranks in the upper third of schools in the state in the number of teachers who leave their positions.  a "hard-to-staff position" is defined as a teaching category (such as special education, mathematics, or science) in which statewide data compiled by the state board of education indicates a multi-year pattern of substantial teacher shortage or that has been identified as a critical need by the school board.
# Validation Result: incorrect
# Time Taken: 21.08 seconds
#
# --------------------------------------------------------------------------------
# Processing question 18 out of 30
# Question 18: What financial information must Illinois public universities provide on an undergraduate tuition bill?
# Ground Truth: Illinois public universities must provide a statement on or with the tuition bill that details: 1. The total amount of financial support the university received from the General Assembly and the Governor, including amounts from the General Revenue Fund and the Education Assistance Fund.2. The average tuition subsidy received by resident undergraduate full-time students.
# RAG Response: illinois public universities must include the following information on undergraduate tuition bills:
#
# * **the total amount of state appropriations authorized for public university operations from the general revenue fund and the education assistance fund for that fiscal year.**
# * **the average tuition subsidy amount per resident undergraduate full-time student from the state of illinois for that fiscal year.**  this subsidy amount represents the portion of instructional costs covered by the state and is used to offset the total cost of instruction.
# Validation Result: correct
# Time Taken: 17.51 seconds
#
# --------------------------------------------------------------------------------
# Processing question 19 out of 30
# Question 19: Who is responsible for calculating the average tuition subsidy provided to students in Illinois public universities, and when is this information shared?
# Ground Truth: The Illinois Board of Higher Education is responsible and must provide the calculation to universities by March 1 of each year.
# RAG Response: the illinois board of higher education calculates the average tuition subsidy.  they provide this calculation to all public universities by march 1st of each year.
# Validation Result: correct
# Time Taken: 14.64 seconds
#
# --------------------------------------------------------------------------------
# Processing question 20 out of 30
# Question 20: By what date must institutions report their financial-based transcript hold policies and statistics?
# Ground Truth: Institutions of higher education in Illinois must report this information on or before July 1, 2024, and on or before each July 1 thereafter.
# RAG Response: the text specifies that public universities must report information regarding financial-based transcript and registration holds to either the board of higher education or the illinois community college board.  the required information includes (1) the institution's policy and (2) the number of students impacted, using data from the *previous academic year*. however, the text *does not specify a date* by which this information must be submitted.
# Validation Result: incorrect
# Time Taken: 15.97 seconds
#
# --------------------------------------------------------------------------------
# Processing question 21 out of 30
# Question 21: What expenses are reimbursed for members of the State Banking Board of Illinois?
# Ground Truth: Members are reimbursed for ordinary and necessary expenses incurred in attending board meetings.
# RAG Response: members of the state banking board of illinois are reimbursed for ordinary and necessary expenses incurred in attending meetings of the board.
# Validation Result: correct
# Time Taken: 13.84 seconds
#
# --------------------------------------------------------------------------------
# Processing question 22 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Question 22: What is required to operate a community currency exchange?
# Ground Truth: A separate, non-transferable license for each location is required to operate a community currency exchange.  The license is obtained from the Secretary of Financial and Professional Regulation after a thorough application and investigation process.
# RAG Response: the provided text details numerous requirements for obtaining a license to operate a community currency exchange, including:
#
# * **application:** a detailed application containing information about the applicant (name, address, business experience, finances, etc.), the location of the proposed exchange, and any previous connections to currency exchanges. if the applicant is a partnership or corporation, information is required for each partner or controlling person.
# * **investigation:** the secretary of financial and professional regulation will investigate the community's need for a currency exchange at the specified location and the potential impact on existing exchanges.
# * **financial stability:**  applicants must demonstrate financial stability and maintain specific minimum amounts of liquid funds.
# * **bonding:**  licensees must provide a surety bond or proof of a blanket bond.
# * **fees:** various fees are required for applications, investigations, and annual licenses.
# * **record keeping and reporting:** licensees must maintain records and submit annual reports.
# * **community needs:** the proposed currency exchange must promote the needs, convenience, and advantage of the community.
# * **other requirements:** the text mentions other requirements relating to changes of address or ownership, termination of the business, permissible activities, and more.
# Validation Result: correct
# Time Taken: 58.32 seconds
#
# --------------------------------------------------------------------------------
# Processing question 23 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Question 23: How is the annual license fee for a community currency exchange determined?
# Ground Truth: The annual license fee for a community currency exchange is $400 per location and an additional $400 for each additional licensed location.
# RAG Response: the annual license fee for a community currency exchange in illinois is $400 for each licensee and an additional $400 for each additional licensed location.
# Validation Result: incorrect
# Time Taken: 35.03 seconds
#
# --------------------------------------------------------------------------------
# Processing question 24 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 24 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 25 out of 30
# Question 25: What responsibilities does a foreign banking corporation have regarding a registered agent and office in Illinois?
# Ground Truth: The corporation must maintain a registered office and a registered agent in Illinois, with provisions to change or update this information as needed.
# RAG Response: a foreign banking corporation must maintain a registered office and agent in illinois.  205 ilcs 645/5(2) requires delivery to the commissioner of a copy of its registered office designation and registered agent designation.
# Validation Result: correct
# Time Taken: 28.19 seconds
#
# --------------------------------------------------------------------------------
# Processing question 26 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 26 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 27 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 27 after 2 retries.
# Last exception: RAG content is blocked or empty.
# Processing question 28 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Question 28: What legal and regulatory mechanisms are supported for blockchain and financial technology adoption?
# Ground Truth: Mechanisms that enable and promote the adoption of blockchain and financial technology in the state are included in promotional efforts.
# RAG Response: i'm sorry, but the provided text does not contain the answer to this question. while the text discusses a variety of topics related to illinois state government initiatives, it does not specifically address any legal or regulatory mechanisms for blockchain or financial technology adoption.
# Validation Result: incorrect
# Time Taken: 28.83 seconds
#
# --------------------------------------------------------------------------------
# Processing question 29 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Question 29: What industries are targeted for economic development using blockchain and financial technology?
# Ground Truth: Banking, insurance, retail and service businesses, and cryptocurrency for blockchain technology and financial technology-related economic development.
# RAG Response: i'm sorry, but the provided text does not mention which industries are targeted for economic development using blockchain and financial technology in illinois.  while it discusses various programs and initiatives aimed at fostering technological growth and innovation, including references to technology transfer, research and development, and venture capital, there is no specific mention of blockchain or fintech as targeted industries.
# Validation Result: incorrect
# Time Taken: 27.97 seconds
#
# --------------------------------------------------------------------------------
# Processing question 30 out of 30
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Error encountered while generating RAG response: RAG response indicates insufficient information.
# Failed to get a response for question 30 after 2 retries.
# Last exception: RAG content is blocked or empty.
#
# Final Results for RAG System:
# Model: RAG
# Total Questions Evaluated: 30
# Correctly Matched Answers: 10
# Accuracy: 33.33%
# Total Time: 1178.58 seconds
# Average Time per Question: 37.91 seconds
# ====================================================================================================

# %% [markdown]
# ## Important Note on LLM Evaluation
#
# While the LLM provides valuable assistance in evaluating model responses and their correctness, it is not guaranteed to be 100% accurate. We highly recommend **double-checking the evaluation results manually** to ensure reliability and accuracy.
#
# The **final decision** should always be made by a human, using the LLM's evaluation as a reference rather than the sole determinant.

# %% [markdown]
# # Benchmark Analysis: Simple RAG Results
#
# This benchmark evaluates the performance of the Simple RAG system on binary and short-answer questions. **Note**: The results have been manually verified for accuracy. Additionally, the benchmark outcomes may vary slightly each time the code is executed due to the nature of the underlying models and system behavior.
#
# ## Binary Questions
# - **Average Time per Question**: 27.9 seconds
# - **Questions Evaluated**: 15
# - **Correctly Answered**: 12
# - **Accuracy**: 80.0%
#
# ## Short Answer Questions
# - **Average Time per Question**: 37.9 seconds
# - **Questions Evaluated**: 30
# - **Correctly Answered**: 11
# - **Accuracy**: 36.7%
